# %%
file = open("sobrepython.txt", "r", encoding="utf-8")

# %%
file
# Out:
# <_io.TextIOWrapper name='sobrepython.txt' mode='r' encoding='utf-8'>

# %%
file.readlines()
# Out:
# ['Python é uma linguagem de programação de alto nível,[4] interpretada, de script, imperativa, orientada a objetos, funcional, de tipagem dinâmica e forte. Foi lançada por Guido van Rossum em 1991.[1] Atualmente possui um modelo de desenvolvimento comunitário, aberto e gerenciado pela organização sem fins lucrativos Python Software Foundation. Apesar de várias partes da linguagem possuírem padrões e especificações formais, a linguagem como um todo não é formalmente especificada. O padrão de facto é a implementação CPython.\n',
#  '\n',
#  'A linguagem foi projetada com a filosofia de enfatizar a importância do esforço do programador sobre o esforço computacional. Prioriza a legibilidade do código sobre a velocidade ou expressividade. Combina uma sintaxe concisa e clara com os recursos poderosos de sua biblioteca padrão e por módulos e frameworks desenvolvidos por terceiros.\n',
#  '\n',
# ...

# %%
file.seek(0)
# Out:
# 0

# %%
file.readlines()
# Out:
# ['Python é uma linguagem de programação de alto nível,[4] interpretada, de script, imperativa, orientada a objetos, funcional, de tipagem dinâmica e forte. Foi lançada por Guido van Rossum em 1991.[1] Atualmente possui um modelo de desenvolvimento comunitário, aberto e gerenciado pela organização sem fins lucrativos Python Software Foundation. Apesar de várias partes da linguagem possuírem padrões e especificações formais, a linguagem como um todo não é formalmente especificada. O padrão de facto é a implementação CPython.\n',
#  '\n',
#  'A linguagem foi projetada com a filosofia de enfatizar a importância do esforço do programador sobre o esforço computacional. Prioriza a legibilidade do código sobre a velocidade ou expressividade. Combina uma sintaxe concisa e clara com os recursos poderosos de sua biblioteca padrão e por módulos e frameworks desenvolvidos por terceiros.\n',
#  '\n',
# ...

# %%
file2 = open("AAPL.csv", 'r', encoding="utf-8")

# %%
file2.readlines()
# Out:
# ['Date,Open,High,Low,Close,Adj Close,Volume\n',
#  '2018-07-18,191.779999,191.800003,189.929993,190.399994,187.545181,16393400\n',
#  '2018-07-19,189.690002,192.550003,189.690002,191.880005,189.003006,20286800\n',
#  '2018-07-20,191.779999,192.429993,190.169998,191.440002,188.569595,20676200\n',
#  '2018-07-23,190.679993,191.960007,189.559998,191.610001,188.737030,15989400\n',
#  '2018-07-24,192.449997,193.660004,192.050003,193.000000,190.106216,18697900\n',
#  '2018-07-25,193.059998,194.850006,192.429993,194.820007,191.898926,16709900\n',
#  '2018-07-26,194.610001,195.960007,193.610001,194.210007,191.298080,19076000\n',
#  '2018-07-27,194.990005,195.190002,190.100006,190.979996,188.116501,24024000\n',
#  '2018-07-30,191.899994,192.199997,189.070007,189.910004,187.062546,21029500\n',
#  '2018-07-31,190.300003,192.139999,189.339996,190.289993,187.436829,39373000\n',
#  '2018-08-01,199.130005,201.759995,197.309998,201.500000,198.478760,67935700\n',
# ...

# %%
import pandas as pd

# %%
pd.Series([10,8,7,9])
# Out:
# 0    10
# 1     8
# 2     7
# 3     9
# dtype: int64

# %%
notas = pd.Series([10,8,7,9])

# %%
notas.mean()
# Out:
# 8.5

# %%
notas.sum()
# Out:
# 34

# %%
notas.std()
# Out:
# 1.2909944487358056

# %%
df = pd.DataFrame({"Alunos":["Alfredo", "Abel", \
                             "Henrique", "Julia", \
                            "Carlos"], 
                  "Faltas": [1, 8, 4, 0, 2], 
                  "Prova": [10, 9.8, 4.5, 8.5, 7.8]})

# %%
df.iloc[0]
# Out:
# Alunos    Alfredo
# Faltas          1
# Prova          10
# Name: 0, dtype: object

# %%
df.columns
# Out:
# Index(['Alunos', 'Faltas', 'Prova'], dtype='object')

# %%
df.dtypes
# Out:
# Alunos     object
# Faltas      int64
# Prova     float64
# dtype: object

# %%
df
# Out:
#      Alunos  Faltas  Prova
# 0   Alfredo       1   10.0
# 1      Abel       8    9.8
# 2  Henrique       4    4.5
# 3     Julia       0    8.5
# 4    Carlos       2    7.8

# %%
df[df["Prova"] > 8]
# Out:
#     Alunos  Faltas  Prova
# 0  Alfredo       1   10.0
# 1     Abel       8    9.8
# 3    Julia       0    8.5

# %%
apple = pd.read_csv("AAPL.csv", sep=",")

# %%
apple
# Out:
#            Date        Open        High         Low       Close   Adj Close  \
# 0    2018-07-18  191.779999  191.800003  189.929993  190.399994  187.545181
# 1    2018-07-19  189.690002  192.550003  189.690002  191.880005  189.003006
# 2    2018-07-20  191.779999  192.429993  190.169998  191.440002  188.569595
# 3    2018-07-23  190.679993  191.960007  189.559998  191.610001  188.737030
# 4    2018-07-24  192.449997  193.660004  192.050003  193.000000  190.106216
# 5    2018-07-25  193.059998  194.850006  192.429993  194.820007  191.898926
# 6    2018-07-26  194.610001  195.960007  193.610001  194.210007  191.298080
# 7    2018-07-27  194.990005  195.190002  190.100006  190.979996  188.116501
# 8    2018-07-30  191.899994  192.199997  189.070007  189.910004  187.062546
# 9    2018-07-31  190.300003  192.139999  189.339996  190.289993  187.436829
# 10   2018-08-01  199.130005  201.759995  197.309998  201.500000  198.478760
# ...

# %%
apple.head()
# Out:
#          Date        Open        High         Low       Close   Adj Close  \
# 0  2018-07-18  191.779999  191.800003  189.929993  190.399994  187.545181
# 1  2018-07-19  189.690002  192.550003  189.690002  191.880005  189.003006
# 2  2018-07-20  191.779999  192.429993  190.169998  191.440002  188.569595
# 3  2018-07-23  190.679993  191.960007  189.559998  191.610001  188.737030
# 4  2018-07-24  192.449997  193.660004  192.050003  193.000000  190.106216
#
#      Volume
# 0  16393400
# 1  20286800
# 2  20676200
# 3  15989400
# 4  18697900

# %%
apple.tail(7)[["Adj Close"]].mean()
# Out:
# Adj Close    203.857145
# dtype: float64

# %%
apple.describe()
# Out:
#              Open        High         Low       Close   Adj Close  \
# count  252.000000  252.000000  252.000000  252.000000  252.000000
# mean   192.479325  194.480715  190.559603  192.580437  191.239701
# std     21.630732   21.758249   21.569369   21.644905   21.217154
# min    143.979996  145.720001  142.000000  142.190002  141.039642
# 25%    174.872501  175.967499  173.747501  174.832496  174.111996
# 50%    194.279999  196.165001  192.599998  194.180000  193.582847
# 75%    209.312500  210.074997  206.832497  208.872497  206.713852
# max    230.779999  233.470001  229.779999  232.070007  229.392090
#
#              Volume
# count  2.520000e+02
# mean   3.250815e+07
# std    1.387518e+07
# min    1.136200e+07
# 25%    2.308030e+07
# 50%    2.942395e+07
# 75%    3.876472e+07
# max    9.624670e+07

# %%
url = 'https://www.contextures.com/xlSampleData01.html'

# %%
tabela = pd.read_html(url)

# %%
len(tabela)
# Out:
# 1

# %%
tabela[0]
# Out:
#              0        1         2        3      4         5        6
# 0    OrderDate   Region       Rep     Item  Units  UnitCost    Total
# 1     1/6/2018     East     Jones   Pencil     95      1.99   189.05
# 2    1/23/2018  Central    Kivell   Binder     50     19.99   999.50
# 3     2/9/2018  Central   Jardine   Pencil     36      4.99   179.64
# 4    2/26/2018  Central      Gill      Pen     27     19.99   539.73
# 5    3/15/2018     West   Sorvino   Pencil     56      2.99   167.44
# 6     4/1/2018     East     Jones   Binder     60      4.99   299.40
# 7    4/18/2018  Central   Andrews   Pencil     75      1.99   149.25
# 8     5/5/2018  Central   Jardine   Pencil     90      4.99   449.10
# 9    5/22/2018     West  Thompson   Pencil     32      1.99    63.68
# 10    6/8/2018     East     Jones   Binder     60      8.99   539.40
# 11   6/25/2018  Central    Morgan   Pencil     90      4.99   449.10
# 12   7/12/2018     East    Howard   Binder     29      1.99    57.71
# ...
